# %%
import magpy
import matplotlib.pyplot as plt
import skimage.io as sk_i
from importlib import reload  
import numpy as np
# %matplotlib notebook

# %%
pxpermm = 102.
v =[1650., 1633.]
l=[6.0, -9.2]

# %%
reload(magpy)
imageArray = sk_i.imread(r's0309_20 Side On Interferometry 532nm (1).JPG', as_gray=True)
im_c = magpy.Image(imageArray, 15, pxpermm)
im_c.o = np.array([20., 20.])
w = im_c.px_to_mm(v)
m = im_c.mm_to_px(l)

# %%
im = imageArray
p = v
q = m
fig, ax = plt.subplots()
im_c.plot_px(ax)
ax.scatter(p[0], p[1], c='r')
ax.scatter(q[0], q[1], c='g')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig, ax = plt.subplots()
p = w
q = l
im_c.plot_mm(ax, cmap='viridis')
ax.scatter(p[0], p[1], c='r')
ax.scatter(q[0], q[1], c='g')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
ij = imagej.init()
# Out:
# ---------------------------------------------------------------------------
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-9-a1762181331d> in <module>
# ----> 1 ij = imagej.init()
#
# C:\ProgramData\Anaconda3\lib\site-packages\imagej\__init__.py in init(ij_dir_or_version_or_endpoint, headless)
#     160             sj.config.add_endpoints('net.imagej:imagej:' + version)
#     161
# --> 162     sj.start_jvm()
#     163
#     164     JObjectArray = JArray(JObject)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scyjava\__init__.py in start_jvm(options)
#      43         endpoints = endpoints[:1] + sorted(endpoints[1:])
#      44         _logger.debug('Using endpoints %s', endpoints)
# ---> 45         _, workspace = jgo.resolve_dependencies(
#      46             '+'.join(endpoints),
#      47             m2_repo=scyjava.config.get_m2_repo(),
#
# ...
