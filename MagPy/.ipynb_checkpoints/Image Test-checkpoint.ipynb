# %%
import Image
import matplotlib.pyplot as plt
import skimage.io as sk_i
from importlib import reload  

# %matplotlib notebook

# %%
reload(Image)
pxpermm = 102.
im_c = Image.Image(imageArray, 15, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-8cff027942ab> in <module>
#       2 o = [1563, 833]
#       3 #o = m
# ----> 4 im_c = Image.Image(imageArray, 15, o, 1)
#
# TypeError: __init__() takes 4 positional arguments but 5 were given

# %%
imageArray = sk_i.imread(r's0309_20 Side On Interferometry 532nm (1).JPG', as_gray=True)

# %%
im = imageArray
w = o

# %%
fig, ax = plt.subplots()
ax.imshow(im)
ax.scatter(w[0], w[1], c='r')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
im = im_c.im
w = im_c.o
fig, ax = plt.subplots()
ax.imshow(im)
ax.scatter(w[0], w[1], c='r')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
sh = imageArray.shape
m = [im.shape[1]*.5, im.shape[0]*0.5]
