# %%
import numpy as np
import matplotlib.pyplot as plt
import Ionisation 
from importlib import reload
from scipy.interpolate import interp2d
import requests
# %matplotlib notebook

# %%
reload(Ionisation)
ieaa = Ionisation.IaeaTable(14)
ionisation_model = ieaa.model

# %%
ne1 = 1e17
ne2 = 1e19

T = np.linspace(1,600, 100000)
Z1 = ionisation_model(T, ne1)
Z2 = ionisation_model(T, ne2)

fig, ax = plt.subplots()
ax.semilogx(T, Z1, label='ne=1e17 pcc')
ax.semilogx(T, Z2, label='ne=1e19 pcc')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
